# %% [markdown]
# # Análise de dados usando o Spark

# %% [markdown]
# ### Esse estudo será desenvolvido a partir de duas bases da NASA que contêm dados sobre requisições HTTP para seus servidores com o objetivo de checar as seguintes informações:
#
# 1. Qual é o número de hosts únicos?
# 2. Quantas vezes o erro 404 ocorreu?
# 3. Quais são as 5 principais URLs responsáveis por isso?
# 4. Quantidade de erros 404 por dia.
# 5. O total de bytes retornados.

# %% [markdown]
# ### Importando as bibliotecas do Spark

# %%
#Importando o Findspark que permite importar o PySpark como uma biblioteca do Python
import findspark
findspark.init()

#Importando o PySpark
import pyspark

#Importando todas as funções PySpark SQL
from pyspark.sql.functions import *

#Importando o recurso "SparkSession", fundamental para trabalharmos com Dataframes no Spark
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# ### Importando as bases de dados da NASA

# %%
#O Spark possui um método para importarmos arquivos CSV e convertê-los em Dataframes
nasa1 = spark.read.csv("access_log_Jul95.csv")
nasa2 = spark.read.csv("access_log_Aug95.csv")

# %% [markdown]
# ### Juntando os dois Dataframes

# %%
#O método "union" gera um novo Dataframe através da união de dois Dataframes.
#Essa união vai levar em consideração a posição das colunas e não os seus nomes.
#Então, caso o número de colunas seja diferente entre os dois Dataframes, 
#o Dataframe com menor número de colunas terá novas colunas preenchidas com valor nulo 

df = nasa1.union(nasa2)

# %%
#Usado para testes
df = nasa1

# %%
df.show(5)
# Out:
# +--------------------+
# |                 _c0|
# +--------------------+
# |199.72.81.55 - - ...|
# |unicomp6.unicomp....|
# |199.120.110.21 - ...|
# |burger.letters.co...|
# |199.120.110.21 - ...|
# +--------------------+
# only showing top 5 rows

# %%
df.collect()[0:10]
# Out:
# [Row(_c0='199.72.81.55 - - [01/Jul/1995:00:00:01 -0400] "GET /history/apollo/ HTTP/1.0" 200 6245'),
#  Row(_c0='unicomp6.unicomp.net - - [01/Jul/1995:00:00:06 -0400] "GET /shuttle/countdown/ HTTP/1.0" 200 3985'),
#  Row(_c0='199.120.110.21 - - [01/Jul/1995:00:00:09 -0400] "GET /shuttle/missions/sts-73/mission-sts-73.html HTTP/1.0" 200 4085'),
#  Row(_c0='burger.letters.com - - [01/Jul/1995:00:00:11 -0400] "GET /shuttle/countdown/liftoff.html HTTP/1.0" 304 0'),
#  Row(_c0='199.120.110.21 - - [01/Jul/1995:00:00:11 -0400] "GET /shuttle/missions/sts-73/sts-73-patch-small.gif HTTP/1.0" 200 4179'),
#  Row(_c0='burger.letters.com - - [01/Jul/1995:00:00:12 -0400] "GET /images/NASA-logosmall.gif HTTP/1.0" 304 0'),
#  Row(_c0='burger.letters.com - - [01/Jul/1995:00:00:12 -0400] "GET /shuttle/countdown/video/livevideo.gif HTTP/1.0" 200 0'),
#  Row(_c0='205.212.115.106 - - [01/Jul/1995:00:00:12 -0400] "GET /shuttle/countdown/countdown.html HTTP/1.0" 200 3985'),
#  Row(_c0='d104.aa.net - - [01/Jul/1995:00:00:13 -0400] "GET /shuttle/countdown/ HTTP/1.0" 200 3985'),
#  Row(_c0='129.94.144.152 - - [01/Jul/1995:00:00:13 -0400] "GET / HTTP/1.0" 200 7074')]

# %%
df1 = df#.withColumnRenamed("_c0","nova")

# %%
df1.show(5)
# Out:
# +--------------------+
# |                 _c0|
# +--------------------+
# |199.72.81.55 - - ...|
# |unicomp6.unicomp....|
# |199.120.110.21 - ...|
# |burger.letters.co...|
# |199.120.110.21 - ...|
# +--------------------+
# only showing top 5 rows

# %%
df2 = df1.withColumn('_c0', regexp_replace('_c0', '(.*) - - \[(.*)\] "(.*)" (\d*) (.*)', '$1,$2,$3,$4,$5'))

# %%
df2.collect()[5]
# Out:
# Row(_c0='burger.letters.com,01/Jul/1995:00:00:12 -0400,GET /images/NASA-logosmall.gif HTTP/1.0,304,0')

# %%
df3 = df2.withColumn('_c0', split('_c0', ','))

# %%
df3.collect()[5]
# Out:
# Row(_c0=['burger.letters.com', '01/Jul/1995:00:00:12 -0400', 'GET /images/NASA-logosmall.gif HTTP/1.0', '304', '0'])

# %%
columns_name = ["host","timestamp","request_type","http_status","returned_bytes"]

# %%
df4 = df3.select(*(col('_c0').getItem(i).alias(columns_name[i]) for i in range(5)))

# %%
df4.collect()[5]
# Out:
# Row(host='burger.letters.com', timestamp='01/Jul/1995:00:00:12 -0400', request_type='GET /images/NASA-logosmall.gif HTTP/1.0', http_status='304', returned_bytes='0')

# %%
df4.show()
# Out:
# +--------------------+--------------------+--------------------+-----------+--------------+
# |                host|           timestamp|        request_type|http_status|returned_bytes|
# +--------------------+--------------------+--------------------+-----------+--------------+
# |        199.72.81.55|01/Jul/1995:00:00...|GET /history/apol...|        200|          6245|
# |unicomp6.unicomp.net|01/Jul/1995:00:00...|GET /shuttle/coun...|        200|          3985|
# |      199.120.110.21|01/Jul/1995:00:00...|GET /shuttle/miss...|        200|          4085|
# |  burger.letters.com|01/Jul/1995:00:00...|GET /shuttle/coun...|        304|             0|
# |      199.120.110.21|01/Jul/1995:00:00...|GET /shuttle/miss...|        200|          4179|
# |  burger.letters.com|01/Jul/1995:00:00...|GET /images/NASA-...|        304|             0|
# |  burger.letters.com|01/Jul/1995:00:00...|GET /shuttle/coun...|        200|             0|
# |     205.212.115.106|01/Jul/1995:00:00...|GET /shuttle/coun...|        200|          3985|
# |         d104.aa.net|01/Jul/1995:00:00...|GET /shuttle/coun...|        200|          3985|
# |      129.94.144.152|01/Jul/1995:00:00...|      GET / HTTP/1.0|        200|          7074|
# |unicomp6.unicomp.net|01/Jul/1995:00:00...|GET /shuttle/coun...|        200|         40310|
# |unicomp6.unicomp.net|01/Jul/1995:00:00...|GET /images/NASA-...|        200|           786|
# |unicomp6.unicomp.net|01/Jul/1995:00:00...|GET /images/KSC-l...|        200|          1204|
# |         d104.aa.net|01/Jul/1995:00:00...|GET /shuttle/coun...|        200|         40310|
# |         d104.aa.net|01/Jul/1995:00:00...|GET /images/NASA-...|        200|           786|
# |         d104.aa.net|01/Jul/1995:00:00...|GET /images/KSC-l...|        200|          1204|
# |      129.94.144.152|01/Jul/1995:00:00...|GET /images/ksclo...|        304|             0|
# |      199.120.110.21|01/Jul/1995:00:00...|GET /images/launc...|        200|          1713|
# |ppptky391.asahi-n...|01/Jul/1995:00:00...|GET /facts/about_...|        200|          3977|
# |  net-1-141.eden.com|01/Jul/1995:00:00...|GET /shuttle/miss...|        200|         34029|
# +--------------------+--------------------+--------------------+-----------+--------------+
# only showing top 20 rows

# %%
df4.agg(countDistinct(df4.host).alias('distinct_hosts')).collect()
# Out:
# [Row(distinct_hosts=119852)]

# %%
df4.agg(count(df4.http_status).alias('404_quantity')).collect()
# Out:
# [Row(404_quantity=1853780)]

# %%
df4.groupBy("http_status").count().orderBy("http_status").show()
# Out:
# +-----------+-------+
# |http_status|  count|
# +-----------+-------+
# |       null|  37935|
# |        200|1701488|
# |        302|   8726|
# |        304| 132627|
# |        400|      5|
# |        403|     54|
# |        404|  10804|
# |        500|     62|
# |        501|     14|
# +-----------+-------+

# %%
df4.createOrReplaceTempView("nasa_db")

# %%
spark.sql("SELECT COUNT('http_status') AS 404_error_quantity, host from nasa_db where http_status='404' GROUP BY host ORDER BY COUNT('http_status') DESC LIMIT 5").collect()
# Out:
# [Row(404_error_quantity=251, host='hoohoo.ncsa.uiuc.edu'),
#  Row(404_error_quantity=131, host='jbiagioni.npt.nuwc.navy.mil'),
#  Row(404_error_quantity=110, host='piweba3y.prodigy.com'),
#  Row(404_error_quantity=92, host='piweba1y.prodigy.com'),
#  Row(404_error_quantity=64, host='phaelon.ksc.nasa.gov')]

# %%
spark.sql("SELECT COUNT('http_status') AS 404_error_quantity_by_day, timestamp from nasa_db where http_status='404' GROUP BY timestamp ORDER BY COUNT('http_status') DESC").collect()
# Out:
# [Row(404_error_quantity_by_day=5, timestamp='12/Jul/1995:10:21:30 -0400'),
#  Row(404_error_quantity_by_day=5, timestamp='12/Jul/1995:10:35:12 -0400'),
#  Row(404_error_quantity_by_day=5, timestamp='12/Jul/1995:10:20:43 -0400'),
#  Row(404_error_quantity_by_day=5, timestamp='12/Jul/1995:10:35:11 -0400'),
#  Row(404_error_quantity_by_day=5, timestamp='12/Jul/1995:10:35:09 -0400'),
#  Row(404_error_quantity_by_day=5, timestamp='12/Jul/1995:10:24:50 -0400'),
#  Row(404_error_quantity_by_day=5, timestamp='11/Jul/1995:14:08:06 -0400'),
#  Row(404_error_quantity_by_day=4, timestamp='20/Jul/1995:07:21:17 -0400'),
#  Row(404_error_quantity_by_day=4, timestamp='12/Jul/1995:10:35:03 -0400'),
#  Row(404_error_quantity_by_day=4, timestamp='06/Jul/1995:10:31:11 -0400'),
#  Row(404_error_quantity_by_day=4, timestamp='12/Jul/1995:10:21:32 -0400'),
#  Row(404_error_quantity_by_day=4, timestamp='12/Jul/1995:10:35:01 -0400'),
#  Row(404_error_quantity_by_day=3, timestamp='12/Jul/1995:10:23:35 -0400'),
#  Row(404_error_quantity_by_day=3, timestamp='11/Jul/1995:14:08:20 -0400'),
#  Row(404_error_quantity_by_day=3, timestamp='12/Jul/1995:10:21:29 -0400'),
#  Row(404_error_quantity_by_day=3, timestamp='12/Jul/1995:10:23:38 -0400'),
#  Row(404_error_quantity_by_day=3, timestamp='06/Jul/1995:10:31:12 -0400'),
#  Row(404_error_quantity_by_day=3, timestamp='11/Jul/1995:14:08:36 -0400'),
#  Row(404_error_quantity_by_day=3, timestamp='12/Jul/1995:10:20:44 -0400'),
#  Row(404_error_quantity_by_day=3, timestamp='12/Jul/1995:10:21:28 -0400'),
#  Row(404_error_quantity_by_day=3, timestamp='20/Jul/1995:03:29:20 -0400'),
#  Row(404_error_quantity_by_day=3, timestamp='20/Jul/1995:23:47:33 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='17/Jul/1995:12:04:02 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='14/Jul/1995:15:50:31 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='19/Jul/1995:07:23:00 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='10/Jul/1995:05:06:57 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='21/Jul/1995:11:42:53 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='22/Jul/1995:11:20:19 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='13/Jul/1995:16:28:10 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='26/Jul/1995:08:11:47 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='22/Jul/1995:23:09:33 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='23/Jul/1995:21:34:50 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='10/Jul/1995:19:47:27 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='14/Jul/1995:08:48:59 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='14/Jul/1995:16:11:00 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='06/Jul/1995:23:32:25 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='24/Jul/1995:15:18:56 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='12/Jul/1995:12:30:48 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='13/Jul/1995:07:29:40 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='05/Jul/1995:12:33:37 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='10/Jul/1995:12:05:04 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='10/Jul/1995:20:05:25 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='19/Jul/1995:13:35:57 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='25/Jul/1995:11:37:38 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='14/Jul/1995:12:13:22 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='06/Jul/1995:08:34:12 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='23/Jul/1995:21:33:54 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='24/Jul/1995:11:21:35 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='19/Jul/1995:07:29:56 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='03/Jul/1995:21:59:46 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='12/Jul/1995:16:38:10 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='19/Jul/1995:13:49:03 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='25/Jul/1995:11:37:31 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='12/Jul/1995:21:35:43 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='23/Jul/1995:15:59:33 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='17/Jul/1995:10:32:42 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='19/Jul/1995:11:34:25 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='18/Jul/1995:15:14:34 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='11/Jul/1995:15:37:07 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='19/Jul/1995:07:36:57 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='10/Jul/1995:12:05:17 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='13/Jul/1995:20:49:10 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='05/Jul/1995:15:55:48 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='19/Jul/1995:13:51:02 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='25/Jul/1995:11:37:57 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='01/Jul/1995:03:45:29 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='09/Jul/1995:22:15:33 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='19/Jul/1995:07:29:46 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='14/Jul/1995:15:36:06 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='02/Jul/1995:22:27:46 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='19/Jul/1995:17:27:53 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='06/Jul/1995:10:31:13 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='05/Jul/1995:19:29:06 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='15/Jul/1995:02:34:24 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='13/Jul/1995:14:16:08 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='03/Jul/1995:21:59:43 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='17/Jul/1995:10:53:31 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='18/Jul/1995:03:14:20 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='08/Jul/1995:09:29:48 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='19/Jul/1995:15:10:13 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='19/Jul/1995:12:13:04 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='19/Jul/1995:11:31:14 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='13/Jul/1995:20:49:45 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='03/Jul/1995:16:15:37 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='14/Jul/1995:04:03:08 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='10/Jul/1995:15:22:21 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='07/Jul/1995:22:37:11 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='16/Jul/1995:21:35:15 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='13/Jul/1995:20:48:54 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='18/Jul/1995:15:49:58 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='19/Jul/1995:11:48:14 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='20/Jul/1995:23:47:34 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='13/Jul/1995:16:43:25 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='25/Jul/1995:18:14:10 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='16/Jul/1995:19:33:42 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='06/Jul/1995:11:01:05 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='17/Jul/1995:08:12:00 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='14/Jul/1995:14:06:48 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='07/Jul/1995:04:17:48 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='21/Jul/1995:11:40:45 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='19/Jul/1995:12:27:45 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='09/Jul/1995:17:15:50 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='14/Jul/1995:13:44:17 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='13/Jul/1995:16:23:14 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='23/Jul/1995:03:20:24 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='19/Jul/1995:17:29:24 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='06/Jul/1995:16:03:11 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='13/Jul/1995:16:27:26 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='12/Jul/1995:10:25:06 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='08/Jul/1995:14:36:11 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='11/Jul/1995:00:09:25 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='19/Jul/1995:16:01:58 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='16/Jul/1995:22:38:47 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='27/Jul/1995:09:02:45 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='21/Jul/1995:11:42:16 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='07/Jul/1995:17:55:23 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='04/Jul/1995:16:34:06 -0400'),
#  Row(404_error_quantity_by_day=2, timestamp='11/Jul/1995:18:23:11 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:11:40:47 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:17:57:45 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:21:16:19 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='02/Jul/1995:22:46:55 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:07:15:28 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:14:50:05 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:16:14:43 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='04/Jul/1995:14:59:46 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='04/Jul/1995:19:48:38 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='04/Jul/1995:21:01:22 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:03:31:52 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:05:26:04 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:09:38:33 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:12:00:43 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:17:55:36 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:22:28:12 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:12:55:34 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:07:08:11 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:01:30:42 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:11:07:58 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:16:27:02 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:02:10:26 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:10:12:56 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:15:26:56 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:22:04:17 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:13:12:49 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:13:30:41 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:21:37:17 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:09:39:01 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:11:01:47 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:20:53:23 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='15/Jul/1995:19:13:10 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='15/Jul/1995:21:14:03 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='16/Jul/1995:08:00:01 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:01:24:52 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:13:28:49 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:20:40:00 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:23:29:09 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:13:03:49 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:02:35:58 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:14:50:52 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:16:38:13 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:18:12:15 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:23:58:16 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:23:59:43 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='22/Jul/1995:20:25:29 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='23/Jul/1995:17:35:35 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='23/Jul/1995:19:42:07 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='24/Jul/1995:04:33:47 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='24/Jul/1995:04:56:51 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='24/Jul/1995:15:10:53 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:11:38:15 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:13:28:20 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:00:13:41 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:22:09:12 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:05:17:25 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:15:54:04 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:23:15:08 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:05:55:03 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:11:09:04 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='02/Jul/1995:22:27:44 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:13:49:18 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:19:26:22 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:02:23:50 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:15:57:06 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:17:19:14 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:17:46:18 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:23:55:40 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:00:11:18 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:00:27:22 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:15:52:07 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:16:25:36 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:22:18:46 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:08:36:19 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:10:04:54 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:10:42:12 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:13:27:30 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:06:04:57 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:20:10:12 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:01:49:00 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:18:10:55 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:11:07:27 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:15:32:38 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:20:58:53 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:21:32:26 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:15:15:04 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:22:22:28 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='15/Jul/1995:19:04:08 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='16/Jul/1995:17:15:32 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='16/Jul/1995:22:16:56 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:08:13:07 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:10:06:32 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:12:26:20 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:14:46:36 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:19:46:41 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:07:42:40 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:10:27:05 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:14:08:45 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:14:10:41 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:14:15:00 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:16:00:02 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:17:07:45 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:17:23:19 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:10:05:08 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:11:07:55 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:17:30:53 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:07:18:32 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:18:06:37 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='22/Jul/1995:17:47:43 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='23/Jul/1995:03:04:51 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='24/Jul/1995:12:54:05 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='24/Jul/1995:23:30:37 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:14:59:13 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:15:36:46 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:17:07:22 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:01:54:58 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:00:45:02 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:12:38:00 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:01:09:27 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:10:42:09 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:18:26:12 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:23:26:20 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='02/Jul/1995:20:43:34 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='04/Jul/1995:12:57:37 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:06:08:37 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:10:47:22 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:23:13:01 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:16:14:23 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:19:08:23 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:22:27:10 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:06:19:02 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:14:09:41 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:19:53:08 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:22:46:05 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:04:03:30 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:04:29:09 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:14:28:32 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:21:12:24 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:15:00:41 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:18:02:48 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:22:55:06 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:15:04:13 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:16:14:35 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:22:39:48 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:12:55:45 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:13:33:55 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:17:23:01 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:18:17:29 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:08:46:52 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:10:32:21 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:13:10:08 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:18:10:27 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:11:50:32 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:16:39:16 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='15/Jul/1995:21:07:50 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='16/Jul/1995:12:19:30 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='16/Jul/1995:17:12:33 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='16/Jul/1995:17:50:55 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='16/Jul/1995:19:34:56 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:07:14:29 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:22:22:28 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:10:26:57 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:11:55:26 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:13:16:52 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:23:47:28 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:00:03:54 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:14:58:00 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:19:46:15 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:00:42:08 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:20:50:56 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='23/Jul/1995:00:07:40 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='23/Jul/1995:16:47:38 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:15:44:36 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:22:34:40 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:12:30:54 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:13:39:17 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:14:35:07 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:19:09:30 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:11:32:09 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:14:54:06 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:03:43:26 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:11:51:41 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:12:16:49 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='02/Jul/1995:15:20:18 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:00:00:49 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:17:05:42 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:19:43:47 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:23:12:37 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='04/Jul/1995:10:40:20 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='04/Jul/1995:17:49:52 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:01:53:47 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:08:27:18 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:11:48:58 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:12:19:06 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:20:06:28 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:17:09:16 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:18:28:32 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:19:17:46 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:22:45:28 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:00:33:55 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:15:23:23 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:16:24:44 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:02:34:06 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:11:20:18 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:17:47:42 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:14:30:04 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:22:55:27 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:07:08:40 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:09:38:48 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:10:58:20 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:13:53:57 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:17:32:09 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:08:36:06 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:09:09:13 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:15:00:28 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:22:02:05 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='16/Jul/1995:13:56:23 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='16/Jul/1995:15:00:30 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:00:45:42 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:09:49:57 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:14:08:31 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:15:03:32 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:19:41:48 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:11:35:16 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:09:05:52 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:21:52:40 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='22/Jul/1995:17:54:00 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:13:35:11 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:15:00:29 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:20:00:15 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:14:35:34 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:19:14:05 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:23:46:15 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:12:38:54 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:13:07:04 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:18:58:02 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='02/Jul/1995:00:56:11 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='02/Jul/1995:11:50:09 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='02/Jul/1995:18:21:16 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:12:09:30 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:12:54:17 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='04/Jul/1995:08:34:58 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='04/Jul/1995:15:16:28 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:00:19:10 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:01:04:55 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:01:51:52 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:17:35:28 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:22:17:29 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:22:32:02 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:01:52:39 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:08:15:51 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:03:34:15 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:12:40:51 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:10:51:23 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:11:33:47 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:18:45:35 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:00:53:04 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:14:45:41 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:22:51:13 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:02:31:15 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:08:20:04 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:13:42:32 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:14:22:59 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:20:47:48 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:06:13:41 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:09:07:46 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:11:53:08 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:12:37:43 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:12:58:21 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:14:58:34 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:17:45:10 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='15/Jul/1995:07:17:21 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='15/Jul/1995:21:08:08 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:05:24:59 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:18:27:53 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:03:14:26 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:09:43:43 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:10:24:54 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:19:22:46 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:11:38:49 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:13:34:35 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:15:14:54 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:10:23:48 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:14:04:05 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:14:36:06 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='22/Jul/1995:04:24:35 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='22/Jul/1995:23:13:15 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:12:09:49 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:12:22:52 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:12:38:16 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:12:58:14 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:13:42:51 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:15:30:39 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:17:06:06 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:18:14:09 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:02:11:43 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:04:40:05 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:02:20:46 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:09:02:25 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:17:37:45 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:18:11:03 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:21:23:13 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='02/Jul/1995:09:38:58 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='02/Jul/1995:19:16:20 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:07:44:43 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:08:22:56 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='04/Jul/1995:05:53:27 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:00:20:07 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:14:31:54 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:09:19:58 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:14:42:33 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:19:10:06 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:19:44:58 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:20:55:14 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:15:45:09 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:17:04:08 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:18:37:18 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:02:03:01 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:09:30:54 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:15:06:07 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:16:23:29 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:17:03:14 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:04:41:40 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:11:19:37 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:12:57:37 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:15:31:05 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:15:09:42 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:18:08:49 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:22:51:13 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:07:16:42 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:08:38:50 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:11:13:00 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:12:04:59 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:15:26:14 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:00:52:29 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:09:04:45 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:13:02:18 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:13:15:02 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:17:20:35 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:20:23:41 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:22:20:07 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='15/Jul/1995:10:30:08 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='15/Jul/1995:19:45:00 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:09:21:18 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:10:06:38 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:11:18:33 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:12:20:25 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:12:22:20 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:15:46:23 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:17:49:40 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:15:56:12 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:20:52:13 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:07:11:13 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:15:06:00 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:15:08:14 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:18:58:25 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:07:21:16 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:11:19:52 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:16:14:05 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:13:20:09 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='24/Jul/1995:06:23:34 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:10:07:58 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:16:08:00 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:20:30:03 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:05:46:14 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:09:02:34 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:12:50:10 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:15:27:37 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='28/Jul/1995:05:59:20 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='28/Jul/1995:09:55:27 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:11:27:12 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:23:20:49 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='04/Jul/1995:00:49:42 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:18:42:08 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:11:02:02 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:14:12:58 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:14:50:24 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:19:25:49 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:19:20:52 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:20:30:19 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:17:23:08 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:21:23:19 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:00:07:27 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:19:53:48 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:11:41:34 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:01:09:42 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:11:30:14 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:12:05:28 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:22:44:21 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:01:29:23 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:19:02:01 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:22:51:21 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:09:37:26 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:11:10:47 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:17:24:05 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:09:05:15 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='15/Jul/1995:22:19:25 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='16/Jul/1995:17:51:54 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:13:40:50 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:15:07:23 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:19:19:36 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:14:10:11 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:15:00:29 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:15:13:53 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:14:30:04 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:15:08:17 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:22:30:13 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:14:26:19 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:05:39:03 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:07:18:18 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:09:24:27 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:14:58:16 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:19:17:06 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:20:32:29 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:13:48:55 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:22:25:59 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:00:14:17 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:13:36:50 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:14:58:16 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:23:50:05 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:09:34:39 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='04/Jul/1995:13:36:17 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:00:25:59 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:08:02:00 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:23:30:57 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:23:41:52 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:01:18:24 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:03:26:33 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:13:24:26 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:19:25:28 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:19:28:56 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:04:16:30 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:00:36:18 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:16:42:01 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:09:41:30 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:21:01:14 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:14:42:34 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:21:26:14 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:11:02:45 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:20:32:48 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:05:17:10 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:11:23:44 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:17:01:29 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:19:13:09 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:04:09:17 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:13:57:14 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:17:45:43 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='16/Jul/1995:22:02:02 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='16/Jul/1995:23:27:52 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:12:20:49 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:14:16:24 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:14:16:49 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:10:47:23 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:04:57:35 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:10:40:45 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:16:02:44 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='22/Jul/1995:05:22:42 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='22/Jul/1995:19:16:04 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='23/Jul/1995:23:02:17 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='24/Jul/1995:00:55:14 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='24/Jul/1995:03:07:08 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='24/Jul/1995:09:42:50 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='24/Jul/1995:09:56:46 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='24/Jul/1995:17:36:22 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:11:53:17 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:14:05:06 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:20:19:43 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:11:52:11 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:17:35:47 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:18:40:11 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:13:22:59 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:22:58:38 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='28/Jul/1995:01:39:42 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='28/Jul/1995:12:03:51 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='28/Jul/1995:13:32:11 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='02/Jul/1995:06:36:40 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='02/Jul/1995:12:31:23 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:12:23:20 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:22:32:06 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='04/Jul/1995:06:59:34 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='04/Jul/1995:09:33:17 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:07:00:23 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:08:01:34 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:16:33:29 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:19:17:51 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:23:20:49 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:08:17:49 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:10:12:06 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:11:12:08 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:02:48:02 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:18:13:31 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:22:48:26 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:19:34:01 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:19:44:11 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:20:52:33 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:10:53:24 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:01:08:43 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:10:23:44 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:19:57:49 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:07:29:39 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:11:22:35 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='15/Jul/1995:07:20:25 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='15/Jul/1995:19:44:52 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='15/Jul/1995:20:34:01 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:10:52:50 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:12:21:36 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:12:23:19 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:13:18:42 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:13:51:52 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:11:25:31 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:10:14:24 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:11:39:10 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:14:03:25 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:22:35:30 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:11:12:23 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:16:12:58 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:16:13:46 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:03:40:07 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='23/Jul/1995:05:57:53 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='23/Jul/1995:10:49:31 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='23/Jul/1995:12:53:11 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='23/Jul/1995:23:04:14 -0400'),
# ...
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:13:39:19 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:20:47:57 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:21:35:46 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:10:24:11 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:11:47:05 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:15:57:16 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:00:56:27 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='16/Jul/1995:18:46:38 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:01:25:41 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:12:20:36 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:23:11:05 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:01:08:19 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:07:28:34 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:13:50:21 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:14:09:52 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:16:30:22 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:17:51:39 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:13:19:37 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:14:20:31 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:14:46:27 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:14:42:06 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='23/Jul/1995:00:14:31 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:08:25:00 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:14:36:02 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:00:00:59 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:03:05:00 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:23:13:01 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='28/Jul/1995:03:24:49 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:21:02:44 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:00:24:41 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:02:21:40 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:05:24:27 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:06:47:42 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:13:26:02 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:09:27:43 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:18:35:05 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:20:52:55 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:12:16:55 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:14:06:24 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:22:07:12 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:08:31:43 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:12:35:13 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:14:33:31 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:10:53:16 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:15:38:15 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:13:57:17 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:07:42:26 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:13:01:14 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:01:23:28 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:15:50:22 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='15/Jul/1995:03:32:45 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='15/Jul/1995:18:59:46 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='16/Jul/1995:11:51:18 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:08:13:10 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:12:21:30 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:12:28:58 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:17:05:02 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:00:22:29 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:08:43:24 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:22:26:27 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:12:56:18 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:15:43:29 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:17:40:41 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:17:43:43 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:00:41:20 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:11:52:07 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:11:52:09 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:16:46:35 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:06:05:06 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:07:59:57 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:11:28:38 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:11:57:39 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:14:08:43 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:17:38:07 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:09:25:45 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:14:04:07 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:20:25:14 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='02/Jul/1995:01:24:34 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='02/Jul/1995:02:32:07 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:12:40:30 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:15:27:04 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:23:08:45 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='04/Jul/1995:23:34:12 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:00:24:50 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:02:24:40 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:15:55:24 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:16:22:55 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:17:29:26 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:15:26:50 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:12:15:46 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:16:28:31 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:20:29:24 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:19:47:14 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:01:50:17 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:16:38:19 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:17:32:15 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:17:52:22 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:11:46:20 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:22:51:56 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:08:38:52 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:12:04:48 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:13:30:04 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:16:05:38 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:10:16:40 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='14/Jul/1995:17:16:38 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='15/Jul/1995:00:33:35 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='15/Jul/1995:20:51:40 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='16/Jul/1995:18:33:39 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:12:00:36 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:12:53:50 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='17/Jul/1995:22:10:06 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:09:40:40 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:16:07:38 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:08:46:36 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:11:45:50 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:12:27:38 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:13:55:09 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:15:14:47 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:02:10:02 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:17:30:59 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:17:36:07 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:22:22:11 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:14:00:57 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:18:16:46 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='22/Jul/1995:05:20:16 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='23/Jul/1995:12:47:46 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='24/Jul/1995:03:06:29 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:02:10:55 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:18:40:04 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:07:48:16 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:11:57:34 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='28/Jul/1995:08:52:30 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:14:41:46 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:17:32:18 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:19:08:11 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='02/Jul/1995:00:30:19 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:09:37:16 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:09:48:39 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:16:15:19 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='04/Jul/1995:05:43:33 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='04/Jul/1995:23:26:30 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:00:47:17 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:09:07:53 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:10:16:33 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:22:00:40 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:13:19:48 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:18:59:46 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:23:57:35 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:02:28:56 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:19:08:01 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:14:22:31 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:15:27:33 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:17:04:45 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:23:11:59 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:10:29:55 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:19:59:59 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:23:12:43 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:14:28:41 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:15:23:38 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='12/Jul/1995:21:36:47 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:12:06:24 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='13/Jul/1995:16:25:30 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='15/Jul/1995:00:42:04 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='16/Jul/1995:17:32:16 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='16/Jul/1995:22:20:21 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:02:34:40 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='18/Jul/1995:14:04:36 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:04:04:38 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:04:31:59 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='19/Jul/1995:12:17:16 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='20/Jul/1995:15:16:19 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:03:38:45 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='21/Jul/1995:09:24:34 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='23/Jul/1995:22:05:28 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='24/Jul/1995:14:13:17 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='24/Jul/1995:14:33:35 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='24/Jul/1995:19:49:20 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='25/Jul/1995:14:59:48 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:16:00:37 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:17:08:37 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='26/Jul/1995:20:50:05 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:01:02:18 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='27/Jul/1995:17:38:15 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='28/Jul/1995:00:06:40 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='28/Jul/1995:00:30:36 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='01/Jul/1995:03:19:38 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:07:31:38 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:14:55:12 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='03/Jul/1995:23:52:10 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='04/Jul/1995:01:16:50 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='04/Jul/1995:18:30:24 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='04/Jul/1995:21:56:16 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='04/Jul/1995:23:57:00 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:02:26:27 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:08:47:17 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:14:31:10 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='05/Jul/1995:19:32:25 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:12:46:20 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:16:13:15 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:16:50:34 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='06/Jul/1995:20:27:44 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:01:52:22 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='07/Jul/1995:17:39:43 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='08/Jul/1995:17:59:51 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:02:32:20 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:04:59:09 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:18:51:07 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='09/Jul/1995:20:53:57 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:09:01:39 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:12:17:29 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:13:22:54 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='10/Jul/1995:21:57:30 -0400'),
#  Row(404_error_quantity_by_day=1, timestamp='11/Jul/1995:14:10:19 -0400'),
#  ...]

# %%
df4.printSchema
# Out:
# <bound method DataFrame.printSchema of DataFrame[host: string, timestamp: string, request_type: string, http_status: string, returned_bytes: string]>

# %% [markdown]
# ### Próximos passos:
# #### - Converter schema do Dataframe para otimizar resultados
# ### - Pesquisar sobre como melhorar a performance de processamento

# %% [markdown]
# ### Tudo começa com o primeiro passo. A caminhada continua...
